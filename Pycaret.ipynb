# %% [markdown]
# ## Using Pycaret

# %%
import pandas as pd
from pycaret.classification import *

# %%
df= pd.read_csv('winequality.csv')
df.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
wine= setup(data= df, target='quality', remove_outliers=True, normalize=True, session_id=1)
# Out:
# <style  type="text/css" >
#     #T_62d27257_271d_11eb_803f_d0c5d33d88e1row0_col1 {
#             background-color:  lightgreen;
#         }    #T_62d27257_271d_11eb_803f_d0c5d33d88e1row5_col1 {
#             background-color:  lightgreen;
#         }    #T_62d27257_271d_11eb_803f_d0c5d33d88e1row29_col1 {
#             background-color:  lightgreen;
#         }    #T_62d27257_271d_11eb_803f_d0c5d33d88e1row40_col1 {
#             background-color:  lightgreen;
#         }</style><table id="T_62d27257_271d_11eb_803f_d0c5d33d88e1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_62d27257_271d_11eb_803f_d0c5d33d88e1level0_row0" class="row_heading level0 row0" >0</th>
# ...

# %%
compare_models()
# Out:
# <style  type="text/css" >
#     #T_c3f8669e_271d_11eb_9d37_d0c5d33d88e1 th {
#           text-align: left;
#     }    #T_c3f8669e_271d_11eb_9d37_d0c5d33d88e1row0_col0 {
#             text-align:  left;
#             text-align:  left;
#         }    #T_c3f8669e_271d_11eb_9d37_d0c5d33d88e1row0_col1 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_c3f8669e_271d_11eb_9d37_d0c5d33d88e1row0_col2 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_c3f8669e_271d_11eb_9d37_d0c5d33d88e1row0_col3 {
#             text-align:  left;
#             text-align:  left;
#             : ;
#         }    #T_c3f8669e_271d_11eb_9d37_d0c5d33d88e1row0_col4 {
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }    #T_c3f8669e_271d_11eb_9d37_d0c5d33d88e1row0_col5 {
# ...
